# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'D:\SEMESTER03\DOWLOAD\archive (30)\CarPrice_Assignment.csv')

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
correlation = df.corr()

# %%
correlation
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation,annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
new_df = df[['enginesize','curbweight','carwidth','carlength','wheelbase','stroke','compressionratio','boreratio','peakrpm','horsepower','price']]

# %%
new_df
# Out:
#      enginesize  curbweight  carwidth  carlength  wheelbase  stroke  \
# 0           130        2548      64.1      168.8       88.6    2.68
# 1           130        2548      64.1      168.8       88.6    2.68
# 2           152        2823      65.5      171.2       94.5    3.47
# 3           109        2337      66.2      176.6       99.8    3.40
# 4           136        2824      66.4      176.6       99.4    3.40
# ..          ...         ...       ...        ...        ...     ...
# 200         141        2952      68.9      188.8      109.1    3.15
# 201         141        3049      68.8      188.8      109.1    3.15
# 202         173        3012      68.9      188.8      109.1    2.87
# 203         145        3217      68.9      188.8      109.1    3.40
# 204         141        3062      68.9      188.8      109.1    3.15
#
#      compressionratio  boreratio  peakrpm  horsepower    price
# 0                 9.0       3.47     5000         111  13495.0
# ...

# %%
sns.pairplot(new_df, y_vars=['price'],plot_kws={'alpha': 0.5})
plt.figure(figsize=(12, 10))
plt.show()

# %%
df['aspiration'].unique() #label encoding
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X = new_df.drop(['price'],axis=1)

# %%
Y = new_df.iloc[:,-1:]

# %%
X_train,x_test,Y_train,y_test = train_test_split(X,Y,test_size=0.20,random_state=42)

# %%
new_df.shape
# Out:
# (205, 11)

# %%
Y_train.shape
# Out:
# (164, 1)

# %%
x_test.shape
# Out:
# (41, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
x_test.shape
# Out:
# (41, 10)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred.shape
# Out:
# (41, 1)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absulute = mean_absolute_error(y_test,y_pred)

# %%
mean_absulute
# Out:
# 2609.574456931698

# %%
mean_sq_err = mean_squared_error(y_test,y_pred)

# %%
mean_sq_err
# Out:
# 12732197.948372036

# %%
r2_sc = r2_score(y_test,y_pred)

# %%
r2_sc
# Out:
# 0.8387186539715147

# %%
new_df_copy = new_df.copy()

# %%
new_df_copy
# Out:
#      enginesize  curbweight  carwidth  carlength  wheelbase  stroke  \
# 0           130        2548      64.1      168.8       88.6    2.68
# 1           130        2548      64.1      168.8       88.6    2.68
# 2           152        2823      65.5      171.2       94.5    3.47
# 3           109        2337      66.2      176.6       99.8    3.40
# 4           136        2824      66.4      176.6       99.4    3.40
# ..          ...         ...       ...        ...        ...     ...
# 200         141        2952      68.9      188.8      109.1    3.15
# 201         141        3049      68.8      188.8      109.1    3.15
# 202         173        3012      68.9      188.8      109.1    2.87
# 203         145        3217      68.9      188.8      109.1    3.40
# 204         141        3062      68.9      188.8      109.1    3.15
#
#      compressionratio  boreratio  peakrpm  horsepower    price
# 0                 9.0       3.47     5000         111  13495.0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd = StandardScaler()

# %%
scaled = sd.fit_transform(new_df_copy)

# %%
scaller = pd.DataFrame(scaled,columns = ['enginesize', 'curbweight', 'carwidth', 'carlength', 'wheelbase',
       'stroke', 'compressionratio', 'boreratio', 'peakrpm', 'horsepower',
       'price'])

# %%
scaller
# Out:
#      enginesize  curbweight  carwidth  carlength  wheelbase    stroke  \
# 0      0.074449   -0.014566 -0.844782  -0.426521  -1.690772 -1.839377
# 1      0.074449   -0.014566 -0.844782  -0.426521  -1.690772 -1.839377
# 2      0.604046    0.514882 -0.190566  -0.231513  -0.708596  0.685946
# 3     -0.431076   -0.420797  0.136542   0.207256   0.173698  0.462183
# 4      0.218885    0.516807  0.230001   0.207256   0.107110  0.462183
# ..          ...         ...       ...        ...        ...       ...
# 200    0.339248    0.763241  1.398245   1.198549   1.721873 -0.336970
# 201    0.339248    0.949992  1.351515   1.198549   1.721873 -0.336970
# 202    1.109571    0.878757  1.398245   1.198549   1.721873 -1.232021
# 203    0.435538    1.273437  1.398245   1.198549   1.721873  0.462183
# 204    0.339248    0.975021  1.398245   1.198549   1.721873 -0.336970
#
#      compressionratio  boreratio   peakrpm  horsepower     price
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
cx = scaller.drop(['price'],axis=1)

# %%
cy = scaller.iloc[:,-1:]

# %%
cX_train,cx_test,cY_train,cy_test = train_test_split(cx,cy,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(cX_train,cY_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(cx_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(cy_test,y_pred)

# %%
r2
# Out:
# 0.8387186539715143
