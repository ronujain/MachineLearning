# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'D:\SEMESTER03\DOWLOAD\archive (28)\data.csv')

# %%
output = pd.read_csv(r'D:\SEMESTER03\DOWLOAD\archive (28)\output.csv')

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data['price'].unique()
# Out:
# array([ 313000.      , 2384000.      ,  342000.      , ...,
#         416904.166667,  203400.      ,  220600.      ])

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
new_data = data.drop(['statezip','country','city','street','date'],axis=1)

# %%
new_data
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
# new_data['date'] = pd.to_datetime(new_data['date']).dt.year

# %%
# new_data['date'].unique()

# %%
# new_data.describe()

# %%
correlation = data.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
new_data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated'],
#       dtype='object')

# %%
colu =new_data[['price','bedrooms','bathrooms','sqft_living','sqft_lot','floors','sqft_above','sqft_basement']]

# %%
plt.figure(figsize=(12, 6))
for column in new_data.columns:
    if pd.api.types.is_numeric_dtype(colu):
        plt.subplot(1,1,1,1,1)
        colu.boxplot
        
plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
selected_columns = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

plt.figure(figsize=(12, 6))

for i, column in enumerate(selected_columns):
    if pd.api.types.is_numeric_dtype(new_data[column]):
        plt.subplot(2, 4, i + 1)  # Arrange the subplots in a 2x4 grid
        new_data.boxplot(column=column)
        plt.title(f'Box Plot of {column}')
        plt.suptitle('')
        plt.xlabel('')

plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
sns.pairplot(colu,diag_kind='kde')

# %%
st = new_data[['price', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']]

# %%
X = st.drop(['price'],axis=1)

# %%
X
# Out:
#       bathrooms  sqft_living  sqft_lot  sqft_above  sqft_basement
# 0          1.50         1340      7912        1340              0
# 1          2.50         3650      9050        3370            280
# 2          2.00         1930     11947        1930              0
# 3          2.25         2000      8030        1000           1000
# 4          2.50         1940     10500        1140            800
# ...         ...          ...       ...         ...            ...
# 4595       1.75         1510      6360        1510              0
# 4596       2.50         1460      7573        1460              0
# 4597       2.50         3010      7014        3010              0
# 4598       2.00         2090      6630        1070           1020
# 4599       2.50         1490      8102        1490              0
#
# [4600 rows x 5 columns]

# %%
Y = st.iloc[:,1]

# %%
pd.DataFrame(Y)
# Out:
#       bathrooms
# 0          1.50
# 1          2.50
# 2          2.00
# 3          2.25
# 4          2.50
# ...         ...
# 4595       1.75
# 4596       2.50
# 4597       2.50
# 4598       2.00
# 4599       2.50
#
# [4600 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,Y_train,x_test,y_test = train_test_split(X,Y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
linearreg = LinearRegression()

# %%
linearreg.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_4644\1862795171.py in <module>
# ----> 1 linearreg.fit(X_train,Y_train)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#    1152
#    1153         return wrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     676         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     677
# --> 678         X, y = self._validate_data(
#     679             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680         )
#
# ...
