# %%
# pip install dtreeviz

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg,SVG

# %%
clas = tree.DecisionTreeClassifier(max_depth=3)
iris = load_iris()

X_train = iris.data
Y_train = iris.target
clas.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.375, 0.875, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.25, 0.375, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.125, 0.125, 'gini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.375, 0.125, 'gini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.75, 0.375, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.625, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r'D:\SEMESTER03\MACHINE LEARNING BY AMIIT SIR\decisiontree.xlsx')

# %%
df
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 0        Yes   Yes            Yes        Yes      Yes  Streap Threat
# 1         No    No             No        Yes      Yes        Allergy
# 2        Yes   Yes             No        Yes       No           Cold
# 3        Yes    No            yes         No       No  Streap Threat
# 4         No   Yes             No        Yes       No           Cold
# 5         No    No             NO        Yes       No        Allergy
# 6         No    No            Yes         No       No  Streap Threat
# 7        Yes    No             No        Yes      Yes        Allergy
# 8         No   Yes             No        Yes      Yes           Cold
# 9        Yes    No             No        Yes      Yes           Cold

# %%
def Entropy(S,A,C,T):
     return ((-(S/T)*(np.log2(S/T)))-((C/T)*(np.log2(C/T)))-((A/T)*(np.log2(A/T))))

# %%
entire_entropy = Entropy(3,3,4,10)
print(f"Entropy is {entire_entropy}")
# Out:
# Entropy is 1.5709505944546684

# %%
Sre_Th_Y = df[df['SoreThreat']=='Yes']

# %%
Sre_Th_Y
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 0        Yes   Yes            Yes        Yes      Yes  Streap Threat
# 2        Yes   Yes             No        Yes       No           Cold
# 3        Yes    No            yes         No       No  Streap Threat
# 7        Yes    No             No        Yes      Yes        Allergy
# 9        Yes    No             No        Yes      Yes           Cold

# %%
sore_entro_yes = Entropy(2,1,2,5)
print(f"sore_entro {sore_entro_yes}")
# Out:
# sore_entro 1.5219280948873621

# %%
S_N = df[df['SoreThreat']=='No']

# %%
Sore_En_N0 = Entropy(1,2,2,5)
print(f"Sore_En_N0 {Sore_En_N0}")
# Out:
# Sore_En_N0 1.5219280948873621

# %%
IG01 = entire_entropy - ((5/10)*Sore_En_N0) - ((5/10)*sore_entro_yes)
 
print(f" IG01 is {IG01}")
# Out:
#  IG01 is 0.04902249956730631

# %% [markdown]
# # Fever

# %%
Fever = df[df['Fever']=='Yes']

# %%
Fever
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 0        Yes   Yes            Yes        Yes      Yes  Streap Threat
# 2        Yes   Yes             No        Yes       No           Cold
# 4         No   Yes             No        Yes       No           Cold
# 8         No   Yes             No        Yes      Yes           Cold

# %%
fever_entro_yes = Entropy(1,0,3,4)
fever_entro_yes=0
print(f"fever_entro_yes is {fever_entro_yes}")
# Out:
# fever_entro_yes is 0
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3093374325.py:2: RuntimeWarning: divide by zero encountered in log2
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3093374325.py:2: RuntimeWarning: invalid value encountered in scalar multiply

# %%
Fever = df[df['Fever']=='No']

# %%
Fever
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 1         No    No             No        Yes      Yes        Allergy
# 3        Yes    No            yes         No       No  Streap Threat
# 5         No    No             NO        Yes       No        Allergy
# 6         No    No            Yes         No       No  Streap Threat
# 7        Yes    No             No        Yes      Yes        Allergy
# 9        Yes    No             No        Yes      Yes           Cold

# %%
fever_no = Entropy(2,3,1,6)
print(f"fever_no {fever_no}")
# Out:
# fever_no 1.4591479170272448

# %%
IG02 = entire_entropy - ((4/10)*fever_entro_yes) - ((6/10)*fever_no)
print(f"IG02 is {IG02}")
# Out:
# IG02 is 0.6954618442383216

# %%
Swallen_Glands_yes = df[df['Swallen Glands']=='Yes']

# %%
Swallen_Glands_yes
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 0        Yes   Yes            Yes        Yes      Yes  Streap Threat
# 6         No    No            Yes         No       No  Streap Threat

# %%
Swallen_Glands_yes_entro = Entropy(3,0,0,3)
Swallen_Glands_yes_entro=0
print(f"Swallen_Glands_yes_entro is" + str(Swallen_Glands_yes_entro)
# Out:
#   File "D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_15068\3907919299.py", line 3
#     print(f"Swallen_Glands_yes_entro is" + str(Swallen_Glands_yes_entro)
#                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
Swallen_Glands_No= df[df['Swallen Glands']=='No']

# %%
Swallen_Glands_yes= df[df['Swallen Glands']=='Yes']

# %%
Swallen_Glands_yes
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 0        Yes   Yes            Yes        Yes      Yes  Streap Threat
# 6         No    No            Yes         No       No  Streap Threat

# %%
Swallen_Glands_No
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache Diagnosis
# 1         No    No             No        Yes      Yes   Allergy
# 2        Yes   Yes             No        Yes       No      Cold
# 4         No   Yes             No        Yes       No      Cold
# 7        Yes    No             No        Yes      Yes   Allergy
# 8         No   Yes             No        Yes      Yes      Cold
# 9        Yes    No             No        Yes      Yes      Cold

# %% [markdown]
# Swallen_Glands_No_entro = Entropy(0,2,4,6)

# %%
Swallen_Glands_No_entro = Entropy(0,3,4,7)
Swallen_Glands_No_entro=0
print("Swallen_Glands_No_entro  is  "+ str(Swallen_Glands_No_entro)
# Out:
#   File "D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_15068\3356047799.py", line 3
#     print("Swallen_Glands_No_entro  is  " + str(Swallen_Glands_No_entro)
#                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
IG03 = entire_entropy - ((3/10)*Swallen_Glands_yes_entro) - ((7/10)*Swallen_Glands_No_entro)
print(f"IG03 is {IG03}")
# Out:
# IG03 is 1.5709505944546684

# %% [markdown]
# # Congestion

# %%
Congestion_yes = df[df['Congestion']=='Yes']

# %%
Congestion_no = df[df['Congestion']=='No']

# %%
Congestion_yes
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 0        Yes   Yes            Yes        Yes      Yes  Streap Threat
# 1         No    No             No        Yes      Yes        Allergy
# 2        Yes   Yes             No        Yes       No           Cold
# 4         No   Yes             No        Yes       No           Cold
# 5         No    No             NO        Yes       No        Allergy
# 7        Yes    No             No        Yes      Yes        Allergy
# 8         No   Yes             No        Yes      Yes           Cold
# 9        Yes    No             No        Yes      Yes           Cold

# %%
Congestion_yes_entro = Entropy(1,3,4,8)
print(f" Congestion_yes_entro  is {Congestion_yes_entro}")
# Out:
#  Congestion_yes_entro  is 1.4056390622295665

# %%
Congestion_no
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 3        Yes    No            yes         No       No  Streap Threat
# 6         No    No            Yes         No       No  Streap Threat

# %%
Congestion_No_entro = Entropy(2,0,0,2)
Congestion_No_entro=0
print(f"Congestion_No_entro {Congestion_No_entro}")
# Out:
# Congestion_No_entro 0
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3093374325.py:2: RuntimeWarning: divide by zero encountered in log2
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3093374325.py:2: RuntimeWarning: invalid value encountered in scalar multiply

# %%
IG04 = entire_entropy - ((8/10)* Congestion_yes_entro) - ((2/10)*Congestion_No_entro)
print(f" IG04 is {IG04} ")
# Out:
#  IG04 is 0.4464393446710153

# %%
headache_yes = df[df['headache'] == 'Yes']

# %%
headache_no = df[df['headache'] == 'No']

# %%
headache_yes
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 0        Yes   Yes            Yes        Yes      Yes  Streap Threat
# 1         No    No             No        Yes      Yes        Allergy
# 7        Yes    No             No        Yes      Yes        Allergy
# 8         No   Yes             No        Yes      Yes           Cold
# 9        Yes    No             No        Yes      Yes           Cold

# %%
headache_yes_entro = Entropy(1,2,2,5)
print(f" headache_yes_entro {headache_yes_entro}")
# Out:
#  headache_yes_entro 1.5219280948873621

# %%
headache_no
# Out:
#   SoreThreat Fever Swallen Glands Congestion headache      Diagnosis
# 2        Yes   Yes             No        Yes       No           Cold
# 3        Yes    No            yes         No       No  Streap Threat
# 4         No   Yes             No        Yes       No           Cold
# 5         No    No             NO        Yes       No        Allergy
# 6         No    No            Yes         No       No  Streap Threat

# %%
headache_no_entro = Entropy(2,1,2,5)
print(f" headache_no_entro is  {headache_no_entro}")
# Out:
#  headache_no_entro is  1.5219280948873621

# %%
IG05 = entire_entropy - ((5/10)*headache_yes_entro) - ((5/10)*headache_no_entro)

# %%
print(f" IG05 is  {IG05} ")
# Out:
#  IG05 is  0.04902249956730631

# %%
print(entire_entropy)
# Out:
# 1.5709505944546684

# %%
print(f"ig01 is {IG01}")
print(f"ig02 is {IG02}")
print(f"ig03 is {IG03}")
print(f"ig04 is {IG04}")
print(f"ig05 is {IG05}")
# Out:
# ig01 is 0.04902249956730631
# ig02 is 0.6954618442383216
# ig03 is 1.5709505944546684
# ig04 is 0.4464393446710153
# ig05 is 0.04902249956730631

# %%
data = pd.read_csv(r'D:\SEMESTER03\DOWLOAD\archive (27)\drug200.csv')

# %%
data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
import pandas as  pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = data.iloc[:,: -1]

# %%
Y= data.iloc[:, -1]

# %%
Y
# Out:
# 0      drugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      drugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,Y_train,y_test = train_test_split(X,Y,test_size=0.20)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decisiontree = DecisionTreeClassifier()

# %%
decisiontree.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\1657965456.py in <module>
# ----> 1 decisiontree.fit(X_train,Y_train)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#    1152
#    1153         return wrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input)
#     957         """
#     958
# --> 959         super()._fit(
#     960             X,
#     961             y,
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     240             )
# ...

# %%
new = data.drop(columns=['Na_to_K','Age'])

# %%
new
# Out:
#     Sex      BP Cholesterol   Drug
# 0     F    HIGH        HIGH  drugY
# 1     M     LOW        HIGH  drugC
# 2     M     LOW        HIGH  drugC
# 3     F  NORMAL        HIGH  drugX
# 4     F     LOW        HIGH  drugY
# ..   ..     ...         ...    ...
# 195   F     LOW        HIGH  drugC
# 196   M     LOW        HIGH  drugC
# 197   M  NORMAL        HIGH  drugX
# 198   M  NORMAL      NORMAL  drugX
# 199   F     LOW      NORMAL  drugX
#
# [200 rows x 4 columns]

# %%
new['Drug'].unique()
# Out:
# array(['drugY', 'drugC', 'drugX', 'drugA', 'drugB'], dtype=object)

# %%
def Entropy(Y,C,X,A,B,T):
    return ((-(Y/T)*(np.log2(Y/T)))-((C/T)*(np.log2(C/T)))- ((X/T)*(np.log2(X/T))) - ((A/T)*(np.log2(A/T)))-((B/T)*(np.log2(B/T))))

# %%
Entire_Entropy = Entropy(91,54,23,16,16,200)

# %%
print(f" Entire_Entropy is {Entire_Entropy}")
# Out:
#  Entire_Entropy is 1.968780377953625

# %%
new['Drug'].value_counts()
# Out:
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %% [markdown]
# # Sex

# %%
Sex_M = new[new['Sex']== 'M']

# %%
Sex_M
# Out:
#     Sex      BP Cholesterol   Drug
# 1     M     LOW        HIGH  drugC
# 2     M     LOW        HIGH  drugC
# 7     M     LOW        HIGH  drugC
# 8     M  NORMAL        HIGH  drugY
# 9     M     LOW      NORMAL  drugY
# ..   ..     ...         ...    ...
# 192   M     LOW        HIGH  drugY
# 193   M     LOW        HIGH  drugC
# 196   M     LOW        HIGH  drugC
# 197   M  NORMAL        HIGH  drugX
# 198   M  NORMAL      NORMAL  drugX
#
# [104 rows x 4 columns]

# %%
Sex_M[Sex_M['Drug']=='drugY'].value_counts()
# Out:
# Sex  BP      Cholesterol  Drug
# M    NORMAL  HIGH         drugY    11
#      HIGH    NORMAL       drugY     9
#      LOW     NORMAL       drugY     9
#              HIGH         drugY     8
#      HIGH    HIGH         drugY     6
#      NORMAL  NORMAL       drugY     1
# dtype: int64

# %%
# Y,C,X,A,B,T

# %%
Sex_M_Entro = Entropy(44,9,27,14,10,104)

# %%
print(f" Sex_M_Entro is {Sex_M_Entro}")
# Out:
#  Sex_M_Entro is 2.0499730965149805

# %%
Sex_F = new[new['Sex']== 'F']  # Y,C,X,A,B,T

# %%
Sex_F
# Out:
#     Sex      BP Cholesterol   Drug
# 0     F    HIGH        HIGH  drugY
# 3     F  NORMAL        HIGH  drugX
# 4     F     LOW        HIGH  drugY
# 5     F  NORMAL        HIGH  drugX
# 6     F  NORMAL        HIGH  drugY
# ..   ..     ...         ...    ...
# 184   F    HIGH        HIGH  drugY
# 185   F  NORMAL      NORMAL  drugY
# 194   F    HIGH        HIGH  drugY
# 195   F     LOW        HIGH  drugC
# 199   F     LOW      NORMAL  drugX
#
# [96 rows x 4 columns]

# %%
Sex_F[Sex_F['Drug']=='drugB'].value_counts()
# Out:
# Sex  BP    Cholesterol  Drug
# F    HIGH  NORMAL       drugB    4
#            HIGH         drugB    2
# dtype: int64

# %%
print(47+7+27+9+6)
# Out:
# 96

# %%
Sex_F_Entro = Entropy(47,7,27,9,6,96)

# %%
Sex_F_Entro
# Out:
# 1.8647726771901811

# %%
IG01 = Entire_Entropy - ((104/200) * Sex_M_Entro) - ((96/200)* Sex_F_Entro)

# %%
print(f" IG01 is {IG01} ")
# Out:
#  IG01 is 0.007703482714548349

# %%
new['BP'].unique()
# Out:
# array(['HIGH', 'LOW', 'NORMAL'], dtype=object)

# %%
# Y,C,X,A,B,T

# %%
bpHigh = new[new['BP']== 'HIGH']

# %%
bpHigh.value_counts()
# Out:
# Sex  BP    Cholesterol  Drug
# F    HIGH  NORMAL       drugY    14
#            HIGH         drugY     9
# M    HIGH  NORMAL       drugY     9
#                         drugA     8
# F    HIGH  HIGH         drugA     6
# M    HIGH  HIGH         drugA     6
#                         drugB     6
#                         drugY     6
# F    HIGH  NORMAL       drugB     4
# M    HIGH  NORMAL       drugB     4
# F    HIGH  NORMAL       drugA     3
#            HIGH         drugB     2
# dtype: int64

# %%
bpHigh[bpHigh['Drug']== 'drugB'].value_counts()
# Out:
# Sex  BP    Cholesterol  Drug
# M    HIGH  HIGH         drugB    6
# F    HIGH  NORMAL       drugB    4
# M    HIGH  NORMAL       drugB    4
# F    HIGH  HIGH         drugB    2
# dtype: int64

# %%
EntropyHghBp = Entropy(38,0,0,23,16,77)  # Y,C,X,A,B,T
# Out:
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3837659114.py:2: RuntimeWarning: divide by zero encountered in log2
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3837659114.py:2: RuntimeWarning: invalid value encountered in scalar multiply

# %%
EntropyHghBp=0

# %%
BpNormal = new[new['BP']=='NORMAL']

# %%
BpNormal.value_counts()
# Out:
# Sex  BP      Cholesterol  Drug
# F    NORMAL  HIGH         drugX    12
# M    NORMAL  HIGH         drugY    11
#              NORMAL       drugX     9
#              HIGH         drugX     8
# F    NORMAL  NORMAL       drugX     7
#              HIGH         drugY     6
#              NORMAL       drugY     5
# M    NORMAL  NORMAL       drugY     1
# dtype: int64

# %%
BpNormalEntro = Entropy(23,36,0,0,0,59)       # Y,C,X,A,B,T
# Out:
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3837659114.py:2: RuntimeWarning: divide by zero encountered in log2
# D:\SEMESTER03\SOURABHSIR\TEMP FILES\ipykernel_9120\3837659114.py:2: RuntimeWarning: invalid value encountered in scalar multiply

# %%
def giniImpurity(Y,C,X,A,B,T):
    return  1 - (Y/T)**2 - (C/T)**2  -  (X/T)**2 - (A/T)**2 - (B/T)**2

# %%
entire_gini = giniImpurity(91,54,23,16,16,200)

# %%
print(f"entire_gini {entire_gini}")
# Out:
# entire_gini 0.6940500000000001

# %% [markdown]
# # RANDOM FOREST
